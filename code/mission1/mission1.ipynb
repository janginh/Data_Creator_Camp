# %%
# !pip install ultralytics==8.*
# Out:
# Requirement already satisfied: ultralytics==8.* in c:\users\user\anaconda3\envs\dcc\lib\site-packages (8.3.198)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (0.20.1+cu121)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (7.0.0)
# Requirement already satisfied: polars in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (1.33.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from ultralytics==8.*) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.*) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.*) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.*) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.*) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.*) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.*) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.*) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.*) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from requests>=2.23.0->ultralytics==8.*) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from requests>=2.23.0->ultralytics==8.*) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from requests>=2.23.0->ultralytics==8.*) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from requests>=2.23.0->ultralytics==8.*) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from torch>=1.8.0->ultralytics==8.*) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from torch>=1.8.0->ultralytics==8.*) (4.15.0)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from torch>=1.8.0->ultralytics==8.*) (3.5)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from torch>=1.8.0->ultralytics==8.*) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from torch>=1.8.0->ultralytics==8.*) (2025.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from torch>=1.8.0->ultralytics==8.*) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.*) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\dcc\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics==8.*) (3.0.2)

# %%
# train 데이터 변환
# json파일의 x,y,w,h 바운딩박스의 값을 0~1의 값으로 변환하여 저장
# txt파일에는 class_id와 bbox의 값 x,y,w,h 값이 나오게 된다.
# 해당 과정을 통해 imgsize를 512에서 256으로 학습이 가능하게 됨
# 여러개의 bbox의 경우에는 줄바꿈으로 저장됨
# chi_id가 1~7이면 모두 굴뚝(class 0)으로 처리

import os
import json

input_dir = "TL_KS_BBOX"
output_dir = "labels/train"
os.makedirs(output_dir, exist_ok=True)

# chi_id 1~7 → class 0 (굴뚝)
CLASS_WHITELIST = {str(i) for i in range(1, 8)}  # {"1","2","3","4","5","6","7"}
CHIMNEY_CLASS_ID = 0 #굴뚝이 있다

for filename in os.listdir(input_dir):
    if not filename.endswith(".json"):
        continue

    json_path = os.path.join(input_dir, filename)
    txt_path = os.path.join(output_dir, filename.replace(".json", ".txt"))

    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    lines = []
    # 최상위 키마다 entry 구조 순회
    for _, entry in data.items():
        fa = entry.get("file_attributes", {})
        try:
            img_w = int(float(fa.get("img_width", 0)))
            img_h = int(float(fa.get("img_height", 0)))
        except Exception:
            img_w, img_h = 0, 0
        if img_w <= 0 or img_h <= 0:
            # 이미지 크기 없으면 스킵
            continue

        for region in entry.get("regions", []):
            shape = region.get("shape_attributes", {})
            attrs = region.get("region_attributes", {})

            chi_id = attrs.get("chi_id")
            if chi_id is None:
                continue
            chi_id = str(chi_id).strip()

            # 1~7만 굴뚝으로 사용
            if chi_id not in CLASS_WHITELIST:
                continue

            # 좌표 읽기
            try:
                x = float(shape["x"])
                y = float(shape["y"])
                w = float(shape["width"])
                h = float(shape["height"])
            except Exception:
                continue

            if w <= 0 or h <= 0:
                continue

            # YOLO 정규화 (cx, cy, w, h)
            cx = (x + w/2) / img_w
            cy = (y + h/2) / img_h
            nw =  w / img_w
            nh =  h / img_h

            # 굴뚝 class 0으로 저장
            lines.append(f"{CHIMNEY_CLASS_ID} {cx:.6f} {cy:.6f} {nw:.6f} {nh:.6f}")

    # 라벨 저장 (없으면 빈 파일 생성될 수 있음 → 원치 않으면 if lines: 로 감싸기)
    with open(txt_path, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))

    print(f"YOLO 변환 완료: {json_path} → {txt_path}")

print("작업종료")

# %%
# valid 데이터 변환
# json파일의 x,y,w,h 바운딩박스의 값을 0~1의 값으로 변환하여 저장
# txt파일에는 class_id와 bbox의 값 x,y,w,h 값이 나오게 된다.
# 해당 과정을 통해 imgsize를 512에서 256으로 학습이 가능하게 됨
# 여러개의 bbox의 경우에는 줄바꿈으로 저장됨
# chi_id가 1~7이면 모두 굴뚝(class 0)으로 처리

import os
import json

input_dir = "VL_KS_BBOX_json"
output_dir = "labels/valid"
os.makedirs(output_dir, exist_ok=True)

# chi_id 1~7 → class 0 (굴뚝)
CLASS_WHITELIST = {str(i) for i in range(1, 8)}  # {"1","2","3","4","5","6","7"}
CHIMNEY_CLASS_ID = 0

for filename in os.listdir(input_dir):
    if not filename.endswith(".json"):
        continue

    json_path = os.path.join(input_dir, filename)
    txt_path = os.path.join(output_dir, filename.replace(".json", ".txt"))

    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    lines = []
    # 최상위 키마다 entry 구조 순회
    for _, entry in data.items():
        fa = entry.get("file_attributes", {})
        try:
            img_w = int(float(fa.get("img_width", 0)))
            img_h = int(float(fa.get("img_height", 0)))
        except Exception:
            img_w, img_h = 0, 0
        if img_w <= 0 or img_h <= 0:
            # 이미지 크기 없으면 스킵
            continue

        for region in entry.get("regions", []):
            shape = region.get("shape_attributes", {})
            attrs = region.get("region_attributes", {})

            chi_id = attrs.get("chi_id")
            if chi_id is None:
                continue
            chi_id = str(chi_id).strip()

            # 1~7만 굴뚝으로 사용
            if chi_id not in CLASS_WHITELIST:
                continue

            # 좌표 읽기
            try:
                x = float(shape["x"])
                y = float(shape["y"])
                w = float(shape["width"])
                h = float(shape["height"])
            except Exception:
                continue

            if w <= 0 or h <= 0:
                continue

            # YOLO 정규화 (cx, cy, w, h)
            cx = (x + w/2) / img_w
            cy = (y + h/2) / img_h
            nw =  w / img_w
            nh =  h / img_h

            # 굴뚝 class 0으로 저장
            lines.append(f"{CHIMNEY_CLASS_ID} {cx:.6f} {cy:.6f} {nw:.6f} {nh:.6f}")

    # 라벨 저장 (없으면 빈 파일 생성될 수 있음 → 원치 않으면 if lines: 로 감싸기)
    with open(txt_path, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))

    print(f"YOLO 변환 완료: {json_path} → {txt_path}")

print("작업종료")

# %%
from ultralytics import YOLO

# 1) 모델 로드 (yolov8m)
model = YOLO("yolov8l.pt")

# 2) 학습
results = model.train(
    data="data.yaml",  # 데이터셋 yaml 경로
    conf=0.25,
    iou=0.5,
    max_det=100,
    epochs=100,
    imgsz=512,          # image size
    batch=16,
    workers=4,          # 로더 스레드 수
    project="runs",     # 결과 저장 (시각화)
    name="yolov8l_chimney",  # 실험명
    exist_ok=False,      # 덮어쓰기 허용
    verbose=True,
    patience=20,        # 20epoch 이후에도 성능 향상이 없을시 종료
    seed=42,
)

'''
data.yaml
train: images/train
val : images/valid

names:
  0: chimney
'''

# 3) 검증(선택: best.pt로 val set 평가)
metrics = model.val(data="data.yaml")

# 4) 예측(시각화 저장)
pred = model.predict(
    source="images/val",  # 검즘용 이미지 폴더
    conf=0.25,
    imgsz=512,
    save=True,
    project="runs",
    name="yolov8l_chimney_pred",
    exist_ok=True
)

# Map50 : 0.992

'''
폴더 형태
| mission1
  |--- TL_KS_BBOX (JSON 형태)
  |--- VL_KS_BBOX (JSON 형태)
  |--- images
    |--- trian (TS_KS)
    |--- valid (VS_KS)
  |--- labels
    |--- train (TL_KS_BBOX_TXT) #TXT형태
    |--- valid (VL_KS_BBOX_TXT) #TXT형태
  | mission1.ipynb
  | data.yaml
  
'''
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt': 100% ━━━━━━━━━━━━ 49.7MB 18.5MB/s 2.7s2.7s<0.0s
# New https://pypi.org/project/ultralytics/8.3.199 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.198  Python-3.11.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=0.25, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/mission1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.5, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=100, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8m_chimney, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\USER\Desktop\personal\dcc\mission1\runs\yolov8m_chimney, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\USER\anaconda3\envs\dcc\Lib\site-packages\ultralytics\engine\trainer.py:631, in BaseTrainer.get_dataset(self)
#     625 elif self.args.data.rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     626     "detect",
#     627     "segment",
#     628     "pose",
#     629     "obb",
#     630 }:
# --> 631     data = check_det_dataset(self.args.data)
#     632     if "yaml_file" in data:
#
# File c:\Users\USER\anaconda3\envs\dcc\Lib\site-packages\ultralytics\data\utils.py:405, in check_det_dataset(dataset, autodownload)
#     391 """
#     392 Download, verify, and/or unzip a dataset if not found locally.
#     393
#    (...)    403     (dict[str, Any]): Parsed dataset information and paths.
#     404 """
# --> 405 file = check_file(dataset)
#     407 # Download (optional)
#
# File c:\Users\USER\anaconda3\envs\dcc\Lib\site-packages\ultralytics\utils\checks.py:578, in check_file(file, suffix, download, download_dir, hard)
#     577 if not files and hard:
# --> 578     raise FileNotFoundError(f"'{file}' does not exist")
#     579 elif len(files) > 1 and hard:
#
# FileNotFoundError: '/content/drive/MyDrive/mission1/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 7
#       4 model = YOLO("yolov8m.pt")
#       6 # 2) 학습
# ----> 7 results = model.train(
#       8     data="/content/drive/MyDrive/mission1/data.yaml",  # 데이터셋 yaml 경로
#       9     conf=0.25,
#      10     iou=0.5,
#      11     max_det=100,
#      12     epochs=100,
#      13     imgsz=512,          # 256/320/640 등 가능 (라벨은 정규화라 그대로 사용)
#      14     batch=16,
#      15     workers=4,          # 로더 스레드 수 (환경에 맞게)
#      16     project="runs",     # 결과 저장 루트
#      17     name="yolov8m_chimney",  # 실험명
#      18     exist_ok=False,      # 같은 이름 덮어쓰기 허용
#      19     verbose=True,
#      20     patience=20,        # 20epoch 이후에도 성능 향상이 없을시 종료
#      21     seed=42,
#      22 )
#      24 # 3) 검증(선택: best.pt로 val set 평가)
#      25 metrics = model.val(data="/content/drive/MyDrive/mission1/data.yaml")
#
# File c:\Users\USER\anaconda3\envs\dcc\Lib\site-packages\ultralytics\engine\model.py:795, in Model.train(self, trainer, **kwargs)
#     792 if args.get("resume"):
#     793     args["resume"] = self.ckpt_path
# --> 795 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     796 if not args.get("resume"):  # manually set model only if not resuming
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File c:\Users\USER\anaconda3\envs\dcc\Lib\site-packages\ultralytics\models\yolo\detect\train.py:65, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      56 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks=None):
#      57     """
#      58     Initialize a DetectionTrainer object for training YOLO object detection model training.
#      59
#    (...)     63         _callbacks (list, optional): List of callback functions to be executed during training.
#      64     """
# ---> 65     super().__init__(cfg, overrides, _callbacks)
#
# File c:\Users\USER\anaconda3\envs\dcc\Lib\site-packages\ultralytics\engine\trainer.py:158, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     156 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     157 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 158     self.data = self.get_dataset()
#     160 self.ema = None
#     162 # Optimization utils init
#
# File c:\Users\USER\anaconda3\envs\dcc\Lib\site-packages\ultralytics\engine\trainer.py:635, in BaseTrainer.get_dataset(self)
#     633             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     634 except Exception as e:
# --> 635     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     636 if self.args.single_cls:
#     637     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset '/content/drive/MyDrive/mission1/data.yaml' error  '/content/drive/MyDrive/mission1/data.yaml' does not exist
